# %%
# Install required packages
# %pip install soilgrids

import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import soilgrids
from soilgrids import SoilGrids

# Fix for ModuleNotFoundError: No module named 'pysafe'
# %pip install git+https://github.com/username/pysafe.git

from pysafe import Simulation, Environment, Tree, Crop

# Step 1: Fetch Soil Data (using soilgrids in Python)
latitude = 45.0
longitude = 3.0

# Fetch soil data from SoilGrids
soil = SoilGrids(latitude, longitude)
soil_data = soil.get_properties(properties=[
    'bdod', 'cec', 'clay', 'sand', 'silt', 'ocd', 'phh2o'
])

# Extract relevant properties
soil_df = pd.DataFrame(soil_data)
print("Soil Data:")
print(soil_df)

# Step 2: Fetch Temperature Data (World Bank Climate Data API)
era5_url = "https://climatedataapi.worldbank.org/climateweb/rest/v1/country/annualavg/tas/2020/2040/FRA"
temp_response = requests.get(era5_url).json()

# Extract mean annual temperature
mean_temp = np.mean([item['data'] for item in temp_response[0]['annualData']])
print("Mean Annual Temperature:", mean_temp)

# Step 3: Prepare Data for PySAFE
# Create environment configuration
env = Environment(
    soil_sand=soil_df['sand'].mean(),
    soil_silt=soil_df['silt'].mean(),
    soil_clay=soil_df['clay'].mean(),
    soil_oc=soil_df['ocd'].mean(),
    soil_ph=soil_df['phh2o'].mean(),
    annual_temp=mean_temp
)

# Define a tree and crop species
tree = Tree(species="Walnut", density=10)  # 10 trees per hectare
crop = Crop(species="Wheat")

# Step 4: Run Agroforestry Simulation with PySAFE
simulation = Simulation(
    name="test_simulation",
    environment=env,
    trees=[tree],
    crops=[crop],
    years=20  # Simulate for 20 years
)

results = simulation.run()

# Convert results to DataFrame
results_df = pd.DataFrame(results)
print("Simulation Results:")
print(results_df.head())

# Step 5: Visualize Results
plt.figure(figsize=(10, 6))
plt.plot(results_df['Year'], results_df['CropYield'], label='Crop Yield', color='blue')
plt.plot(results_df['Year'], results_df['TreeYield'], label='Tree Yield', color='green')
plt.xlabel('Year')
plt.ylabel('Yield (tons/ha)')
plt.title('Agroforestry Simulation Results')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Requirement already satisfied: soilgrids in c:\users\paulg\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: bmipy in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (2.0.1)
# Requirement already satisfied: click in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (8.1.7)
# Requirement already satisfied: netcdf4 in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (1.7.2)
# Requirement already satisfied: numpy in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (1.26.4)
# Requirement already satisfied: pyyaml in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (6.0.1)
# Requirement already satisfied: requests in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (2.32.3)
# Requirement already satisfied: rioxarray in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (0.18.2)
# Requirement already satisfied: xarray in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (2025.1.2)
# Requirement already satisfied: owslib in c:\users\paulg\anaconda3\lib\site-packages (from soilgrids) (0.32.1)
# Requirement already satisfied: black in c:\users\paulg\anaconda3\lib\site-packages (from bmipy->soilgrids) (24.8.0)
# Requirement already satisfied: jinja2 in c:\users\paulg\anaconda3\lib\site-packages (from bmipy->soilgrids) (3.1.4)
# Requirement already satisfied: colorama in c:\users\paulg\anaconda3\lib\site-packages (from click->soilgrids) (0.4.6)
# Requirement already satisfied: cftime in c:\users\paulg\anaconda3\lib\site-packages (from netcdf4->soilgrids) (1.6.4.post1)
# Requirement already satisfied: certifi in c:\users\paulg\anaconda3\lib\site-packages (from netcdf4->soilgrids) (2024.8.30)
# Requirement already satisfied: lxml in c:\users\paulg\anaconda3\lib\site-packages (from owslib->soilgrids) (5.2.1)
# Requirement already satisfied: python-dateutil in c:\users\paulg\anaconda3\lib\site-packages (from owslib->soilgrids) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\paulg\anaconda3\lib\site-packages (from requests->soilgrids) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paulg\anaconda3\lib\site-packages (from requests->soilgrids) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paulg\anaconda3\lib\site-packages (from requests->soilgrids) (2.2.3)
# Requirement already satisfied: packaging in c:\users\paulg\anaconda3\lib\site-packages (from rioxarray->soilgrids) (24.1)
# Requirement already satisfied: rasterio>=1.3.7 in c:\users\paulg\anaconda3\lib\site-packages (from rioxarray->soilgrids) (1.4.3)
# Requirement already satisfied: pyproj>=3.3 in c:\users\paulg\anaconda3\lib\site-packages (from rioxarray->soilgrids) (3.7.0)
# Requirement already satisfied: pandas>=2.1 in c:\users\paulg\anaconda3\lib\site-packages (from xarray->soilgrids) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\paulg\anaconda3\lib\site-packages (from pandas>=2.1->xarray->soilgrids) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\paulg\anaconda3\lib\site-packages (from pandas>=2.1->xarray->soilgrids) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\paulg\anaconda3\lib\site-packages (from python-dateutil->owslib->soilgrids) (1.16.0)
# Requirement already satisfied: affine in c:\users\paulg\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray->soilgrids) (2.4.0)
# Requirement already satisfied: attrs in c:\users\paulg\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray->soilgrids) (23.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\paulg\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray->soilgrids) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\paulg\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray->soilgrids) (1.1.1)
# Requirement already satisfied: pyparsing in c:\users\paulg\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray->soilgrids) (3.1.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\paulg\anaconda3\lib\site-packages (from black->bmipy->soilgrids) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\paulg\anaconda3\lib\site-packages (from black->bmipy->soilgrids) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\paulg\anaconda3\lib\site-packages (from black->bmipy->soilgrids) (3.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\paulg\anaconda3\lib\site-packages (from jinja2->bmipy->soilgrids) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/username/pysafe.git
#   Cloning https://github.com/username/pysafe.git to c:\users\paulg\appdata\local\temp\pip-req-build-1jpq2e58
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Error [WinError 2] Le fichier spécifié est introuvable while executing command git version
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 14
#      11 # Fix for ModuleNotFoundError: No module named 'pysafe'
#      12 get_ipython().run_line_magic('pip', 'install git+https://github.com/username/pysafe.git')
# ---> 14 from pysafe import Simulation, Environment, Tree, Crop
#      16 # Step 1: Fetch Soil Data (using soilgrids in Python)
#      17 latitude = 45.0
#
# ModuleNotFoundError: No module named 'pysafe'
